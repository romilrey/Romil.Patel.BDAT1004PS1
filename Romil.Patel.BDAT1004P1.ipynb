# %% [markdown]
# #Question 1.
#
# Question 1:
# •	Int
# •	Float
# •	Relational Operator  (Boolean)
# •	Character
# •	Int
# •	Int
# •	Int
# •	Int
# •	Array
# •	Boolean
# •   Decimal

# %%
# Question 2.a

using Systems;
namespace HelloWorld
{
  class Program
  {
    static void Main(string[] args)
    {
Console.WriteLine("Supercalifragilisticexpialidocious".Contains("ice"));
    }
  }
}
# Out:
#   File "C:\Users\romil\AppData\Local\Temp/ipykernel_8888/546682794.py", line 1
#     using System;
#           ^
# SyntaxError: invalid syntax

# %%
#Question 2.b

using System;
namespace HelloWorld
{
  class Program
  {
    static void Main(string[] args)
    {
Console.WriteLine("Supercalifragilisticexpialidocious".Length);
    }
  }
}

# %%
#Question 2.c

using System;
namespace HelloWorld
{
  class Program
  {
    static void Main(string[] args)
    {
string a = "Supercalifragilisticexpialidocious";
string c = "Honorificabilitudinitatibus";
string b = "Bababadalgharaghtakamminarronnkonn";

if(a.Length > b.Length)
{
	if(a.Length > c.Length)
    	Console.WriteLine(a + " is longest.");
    else if(a.Length == c.Length)
    	Console.WriteLine("Both " + a + " and " + c + " are of same length.");
    else
    	Console.WriteLine(a + " is Longest.");
}
    else if(b.Length > c.Length)
{
	if(
    	Console.WriteLine(b + " is Longest.");
}
else
{
	Console.WriteLine("Both " + a + " and " + b + " are of same length.");
}
    }
  }
}

# %%
#Question 2.d

using System;
namespace HelloWorld
{
  class Program
  {
    static void Main(string[] args)
    {
     String[] arr = {"Berlioz", "Borodin", "Brian",
"Bartok", "Bellini", "Buxtehude", "Bernstein"};
Array.Sort(arr);
Console.WriteLine(arr[0]);
Console.WriteLine(arr[(arr.Length-1)]);

    }
  }
}

# %%
#Question 3

using System;
namespace HelloWorld
{
  class Program
  {
    public double triangleArea(double a, double b, double c)
  {
    double s = (a + b + c) / 2;
    return Math.Sqrt(s * ( s - a) * (s - b) * (s - c));
  }
    static void Main(string[] args)
    {
    
Program obj = new Program();
double area = obj.triangleArea(2,2,2);
Console.WriteLine("Area = {0}", area);
    }
  }
}

# %%
#Question 4

using System;
using System.Collections;
class HelloWorld {
  static void Main() {
    Console.Write("Input the #:");
	  int x = Convert.ToInt32(Console.ReadLine());
    
	  int[] arr = new int[x];
     
     Console.WriteLine("Input numbers");
	 for (int i = 0; i < arr.Length; i++) 
	{
		arr[i] = Convert.ToInt32(Console.ReadLine());
    }
     
     
Console.WriteLine("Ex O/P:");

ArrayList even = new ArrayList();
ArrayList odd = new ArrayList();

foreach (int i in arr){
	if(i%2 == 0)
    	even.Add(i);
     else
     	odd.Add(i);
}
Console.WriteLine("Even:");
foreach(int i in even)
	Console.Write(i + " ");
Console.WriteLine("\nOdd:");
foreach(int i in odd)
	Console.Write(i + " ");
  }
}

# %%
#Question 5.a

using System;

class HelloWorld
{
static bool inside(int x, int y, int x1,
					int y1, int x2, int y2)
{
if (x > x1 && x < x2 &&
	y > y1 && y < y2)
	return true;

return false;
}

public static void Main()
{	
	if (inside(1,1,0,0,2,3))
		Console.WriteLine("True");
	else
		Console.WriteLine("False");

    if (inside(-1,-1,0,0,2,3))
		Console.WriteLine("True");
	else
		Console.WriteLine("False");
}
}
